# %% [markdown]
# # **Hyperparameter Tuning**
# # ⛳

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **PREPARE DATA**

# %%
import pandas as pd
out_df=pd.read_csv("/content/combined_otu_data.tsv", sep='\t')
out_df
# Out:
#                               name  taxonomy_id taxonomy_lvl  \
# 0        Bacteroides xylanisolvens         2057            S
# 1           Bacteroides finegoldii          151            S
# 2               Bacteroides ovatus         2098            S
# 3          Bacteroides sp902362375          104            S
# 4               Bacteroides nordii          546            S
# ...                            ...          ...          ...
# 4625        Campylobacter_D coli_B         3304            S
# 4626        Helicobacter pylori_BU         2194            S
# 4627  Methanobacterium sp000499765           58            S
# 4628           Campylobacter fetus         1077            S
# 4629        Campylobacter_D coli_A         3303            S
#
#       SRR32732804.bracken.out_num  SRR32732804.bracken.out_frac  \
# 0                         3232092                       0.11391
# 1                          851026                       0.02999
# 2                          631604                       0.02226
# 3                          499300                       0.01760
# 4                          123744                       0.00436
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32732805.bracken.out_num  SRR32732805.bracken.out_frac  \
# 0                          383411                       0.01311
# 1                           34049                       0.00116
# 2                          195250                       0.00668
# 3                          117253                       0.00401
# 4                           27246                       0.00093
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32732806.bracken.out_num  SRR32732806.bracken.out_frac  \
# 0                           63773                       0.00160
# 1                           17527                       0.00044
# 2                           53197                       0.00134
# 3                           14670                       0.00037
# 4                            8643                       0.00022
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32732807.bracken.out_num  ...  SRR32733696.bracken.out_num  \
# 0                          204219  ...                       135885
# 1                           51546  ...                        23166
# 2                         4002970  ...                       353907
# 3                           85542  ...                        54273
# 4                          170255  ...                        87856
# ...                           ...  ...                          ...
# 4625                            0  ...                            0
# 4626                            0  ...                            0
# 4627                            0  ...                            0
# 4628                            0  ...                            0
# 4629                            0  ...                            0
#
#       SRR32733696.bracken.out_frac  SRR32733697.bracken.out_num  \
# 0                          0.00387                        61316
# 1                          0.00066                        16353
# 2                          0.01008                         5248
# 3                          0.00155                         4176
# 4                          0.00250                         2923
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32733697.bracken.out_frac  SRR32733698.bracken.out_num  \
# 0                          0.00147                        71793
# 1                          0.00039                       262154
# 2                          0.00013                       245473
# 3                          0.00010                        37103
# 4                          0.00007                        37388
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32733698.bracken.out_frac  SRR32733699.bracken.out_num  \
# 0                          0.00174                        93594
# 1                          0.00634                       215860
# 2                          0.00594                        28510
# 3                          0.00090                         8360
# 4                          0.00090                        14192
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32733699.bracken.out_frac  SRR32733700.bracken.out_num  \
# 0                          0.00320                       195599
# 1                          0.00738                        29743
# 2                          0.00097                       409488
# 3                          0.00029                        67425
# 4                          0.00048                        27676
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32733700.bracken.out_frac
# 0                          0.00405
# 1                          0.00062
# 2                          0.00848
# 3                          0.00140
# 4                          0.00057
# ...                            ...
# 4625                       0.00000
# 4626                       0.00000
# 4627                       0.00000
# 4628                       0.00000
# 4629                       0.00000
#
# [4630 rows x 1705 columns]

# %%
rmv_col=["taxonomy_id",	"taxonomy_lvl"]
imp_col=out_df.drop(rmv_col, axis=1)
imp_col
# Out:
#                               name  SRR32732804.bracken.out_num  \
# 0        Bacteroides xylanisolvens                      3232092
# 1           Bacteroides finegoldii                       851026
# 2               Bacteroides ovatus                       631604
# 3          Bacteroides sp902362375                       499300
# 4               Bacteroides nordii                       123744
# ...                            ...                          ...
# 4625        Campylobacter_D coli_B                            0
# 4626        Helicobacter pylori_BU                            0
# 4627  Methanobacterium sp000499765                            0
# 4628           Campylobacter fetus                            0
# 4629        Campylobacter_D coli_A                            0
#
#       SRR32732804.bracken.out_frac  SRR32732805.bracken.out_num  \
# 0                          0.11391                       383411
# 1                          0.02999                        34049
# 2                          0.02226                       195250
# 3                          0.01760                       117253
# 4                          0.00436                        27246
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32732805.bracken.out_frac  SRR32732806.bracken.out_num  \
# 0                          0.01311                        63773
# 1                          0.00116                        17527
# 2                          0.00668                        53197
# 3                          0.00401                        14670
# 4                          0.00093                         8643
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32732806.bracken.out_frac  SRR32732807.bracken.out_num  \
# 0                          0.00160                       204219
# 1                          0.00044                        51546
# 2                          0.00134                      4002970
# 3                          0.00037                        85542
# 4                          0.00022                       170255
# ...                            ...                          ...
# 4625                       0.00000                            0
# 4626                       0.00000                            0
# 4627                       0.00000                            0
# 4628                       0.00000                            0
# 4629                       0.00000                            0
#
#       SRR32732807.bracken.out_frac  SRR32732808.bracken.out_num  ...  \
# 0                          0.00586                      1464145  ...
# 1                          0.00148                       102643  ...
# 2                          0.11494                      1331243  ...
# 3                          0.00246                       234381  ...
# 4                          0.00489                        31901  ...
# ...                            ...                          ...  ...
# 4625                       0.00000                            0  ...
# 4626                       0.00000                            0  ...
# 4627                       0.00000                            0  ...
# 4628                       0.00000                            0  ...
# 4629                       0.00000                            0  ...
#
#       SRR32733696.bracken.out_num  SRR32733696.bracken.out_frac  \
# 0                          135885                       0.00387
# 1                           23166                       0.00066
# 2                          353907                       0.01008
# 3                           54273                       0.00155
# 4                           87856                       0.00250
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32733697.bracken.out_num  SRR32733697.bracken.out_frac  \
# 0                           61316                       0.00147
# 1                           16353                       0.00039
# 2                            5248                       0.00013
# 3                            4176                       0.00010
# 4                            2923                       0.00007
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32733698.bracken.out_num  SRR32733698.bracken.out_frac  \
# 0                           71793                       0.00174
# 1                          262154                       0.00634
# 2                          245473                       0.00594
# 3                           37103                       0.00090
# 4                           37388                       0.00090
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32733699.bracken.out_num  SRR32733699.bracken.out_frac  \
# 0                           93594                       0.00320
# 1                          215860                       0.00738
# 2                           28510                       0.00097
# 3                            8360                       0.00029
# 4                           14192                       0.00048
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
#       SRR32733700.bracken.out_num  SRR32733700.bracken.out_frac
# 0                          195599                       0.00405
# 1                           29743                       0.00062
# 2                          409488                       0.00848
# 3                           67425                       0.00140
# 4                           27676                       0.00057
# ...                           ...                           ...
# 4625                            0                       0.00000
# 4626                            0                       0.00000
# 4627                            0                       0.00000
# 4628                            0                       0.00000
# 4629                            0                       0.00000
#
# [4630 rows x 1703 columns]

# %%
imp_col.index=out_df['name'].values
imp_col # makes the row labels (index) of imp_col equal to the values in the name column of out_df.
# Out:
#                                                       name  \
# Bacteroides xylanisolvens        Bacteroides xylanisolvens
# Bacteroides finegoldii              Bacteroides finegoldii
# Bacteroides ovatus                      Bacteroides ovatus
# Bacteroides sp902362375            Bacteroides sp902362375
# Bacteroides nordii                      Bacteroides nordii
# ...                                                    ...
# Campylobacter_D coli_B              Campylobacter_D coli_B
# Helicobacter pylori_BU              Helicobacter pylori_BU
# Methanobacterium sp000499765  Methanobacterium sp000499765
# Campylobacter fetus                    Campylobacter fetus
# Campylobacter_D coli_A              Campylobacter_D coli_A
#
#                               SRR32732804.bracken.out_num  \
# Bacteroides xylanisolvens                         3232092
# Bacteroides finegoldii                             851026
# Bacteroides ovatus                                 631604
# Bacteroides sp902362375                            499300
# Bacteroides nordii                                 123744
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732804.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.11391
# Bacteroides finegoldii                             0.02999
# Bacteroides ovatus                                 0.02226
# Bacteroides sp902362375                            0.01760
# Bacteroides nordii                                 0.00436
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32732805.bracken.out_num  \
# Bacteroides xylanisolvens                          383411
# Bacteroides finegoldii                              34049
# Bacteroides ovatus                                 195250
# Bacteroides sp902362375                            117253
# Bacteroides nordii                                  27246
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732805.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.01311
# Bacteroides finegoldii                             0.00116
# Bacteroides ovatus                                 0.00668
# Bacteroides sp902362375                            0.00401
# Bacteroides nordii                                 0.00093
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32732806.bracken.out_num  \
# Bacteroides xylanisolvens                           63773
# Bacteroides finegoldii                              17527
# Bacteroides ovatus                                  53197
# Bacteroides sp902362375                             14670
# Bacteroides nordii                                   8643
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732806.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.00160
# Bacteroides finegoldii                             0.00044
# Bacteroides ovatus                                 0.00134
# Bacteroides sp902362375                            0.00037
# Bacteroides nordii                                 0.00022
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32732807.bracken.out_num  \
# Bacteroides xylanisolvens                          204219
# Bacteroides finegoldii                              51546
# Bacteroides ovatus                                4002970
# Bacteroides sp902362375                             85542
# Bacteroides nordii                                 170255
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732807.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.00586
# Bacteroides finegoldii                             0.00148
# Bacteroides ovatus                                 0.11494
# Bacteroides sp902362375                            0.00246
# Bacteroides nordii                                 0.00489
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32732808.bracken.out_num  ...  \
# Bacteroides xylanisolvens                         1464145  ...
# Bacteroides finegoldii                             102643  ...
# Bacteroides ovatus                                1331243  ...
# Bacteroides sp902362375                            234381  ...
# Bacteroides nordii                                  31901  ...
# ...                                                   ...  ...
# Campylobacter_D coli_B                                  0  ...
# Helicobacter pylori_BU                                  0  ...
# Methanobacterium sp000499765                            0  ...
# Campylobacter fetus                                     0  ...
# Campylobacter_D coli_A                                  0  ...
#
#                               SRR32733696.bracken.out_num  \
# Bacteroides xylanisolvens                          135885
# Bacteroides finegoldii                              23166
# Bacteroides ovatus                                 353907
# Bacteroides sp902362375                             54273
# Bacteroides nordii                                  87856
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733696.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.00387
# Bacteroides finegoldii                             0.00066
# Bacteroides ovatus                                 0.01008
# Bacteroides sp902362375                            0.00155
# Bacteroides nordii                                 0.00250
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32733697.bracken.out_num  \
# Bacteroides xylanisolvens                           61316
# Bacteroides finegoldii                              16353
# Bacteroides ovatus                                   5248
# Bacteroides sp902362375                              4176
# Bacteroides nordii                                   2923
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733697.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.00147
# Bacteroides finegoldii                             0.00039
# Bacteroides ovatus                                 0.00013
# Bacteroides sp902362375                            0.00010
# Bacteroides nordii                                 0.00007
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32733698.bracken.out_num  \
# Bacteroides xylanisolvens                           71793
# Bacteroides finegoldii                             262154
# Bacteroides ovatus                                 245473
# Bacteroides sp902362375                             37103
# Bacteroides nordii                                  37388
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733698.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.00174
# Bacteroides finegoldii                             0.00634
# Bacteroides ovatus                                 0.00594
# Bacteroides sp902362375                            0.00090
# Bacteroides nordii                                 0.00090
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32733699.bracken.out_num  \
# Bacteroides xylanisolvens                           93594
# Bacteroides finegoldii                             215860
# Bacteroides ovatus                                  28510
# Bacteroides sp902362375                              8360
# Bacteroides nordii                                  14192
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733699.bracken.out_frac  \
# Bacteroides xylanisolvens                          0.00320
# Bacteroides finegoldii                             0.00738
# Bacteroides ovatus                                 0.00097
# Bacteroides sp902362375                            0.00029
# Bacteroides nordii                                 0.00048
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
#                               SRR32733700.bracken.out_num  \
# Bacteroides xylanisolvens                          195599
# Bacteroides finegoldii                              29743
# Bacteroides ovatus                                 409488
# Bacteroides sp902362375                             67425
# Bacteroides nordii                                  27676
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733700.bracken.out_frac
# Bacteroides xylanisolvens                          0.00405
# Bacteroides finegoldii                             0.00062
# Bacteroides ovatus                                 0.00848
# Bacteroides sp902362375                            0.00140
# Bacteroides nordii                                 0.00057
# ...                                                    ...
# Campylobacter_D coli_B                             0.00000
# Helicobacter pylori_BU                             0.00000
# Methanobacterium sp000499765                       0.00000
# Campylobacter fetus                                0.00000
# Campylobacter_D coli_A                             0.00000
#
# [4630 rows x 1703 columns]

# %%
num_columns =[col for col in imp_col.columns if col.endswith('_num')]
brack_df = imp_col[num_columns]
brack_df
# Out:
#                               SRR32732804.bracken.out_num  \
# Bacteroides xylanisolvens                         3232092
# Bacteroides finegoldii                             851026
# Bacteroides ovatus                                 631604
# Bacteroides sp902362375                            499300
# Bacteroides nordii                                 123744
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732805.bracken.out_num  \
# Bacteroides xylanisolvens                          383411
# Bacteroides finegoldii                              34049
# Bacteroides ovatus                                 195250
# Bacteroides sp902362375                            117253
# Bacteroides nordii                                  27246
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732806.bracken.out_num  \
# Bacteroides xylanisolvens                           63773
# Bacteroides finegoldii                              17527
# Bacteroides ovatus                                  53197
# Bacteroides sp902362375                             14670
# Bacteroides nordii                                   8643
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732807.bracken.out_num  \
# Bacteroides xylanisolvens                          204219
# Bacteroides finegoldii                              51546
# Bacteroides ovatus                                4002970
# Bacteroides sp902362375                             85542
# Bacteroides nordii                                 170255
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732808.bracken.out_num  \
# Bacteroides xylanisolvens                         1464145
# Bacteroides finegoldii                             102643
# Bacteroides ovatus                                1331243
# Bacteroides sp902362375                            234381
# Bacteroides nordii                                  31901
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732809.bracken.out_num  \
# Bacteroides xylanisolvens                          106125
# Bacteroides finegoldii                               8398
# Bacteroides ovatus                                 101814
# Bacteroides sp902362375                             15628
# Bacteroides nordii                                   3207
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732810.bracken.out_num  \
# Bacteroides xylanisolvens                          274709
# Bacteroides finegoldii                              63793
# Bacteroides ovatus                                 622567
# Bacteroides sp902362375                             98329
# Bacteroides nordii                                  37458
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732811.bracken.out_num  \
# Bacteroides xylanisolvens                          232809
# Bacteroides finegoldii                              45654
# Bacteroides ovatus                                 800555
# Bacteroides sp902362375                            120593
# Bacteroides nordii                                   3211
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732813.bracken.out_num  \
# Bacteroides xylanisolvens                         1179323
# Bacteroides finegoldii                             137449
# Bacteroides ovatus                                2510966
# Bacteroides sp902362375                            384453
# Bacteroides nordii                                  56297
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32732814.bracken.out_num  ...  \
# Bacteroides xylanisolvens                         1384180  ...
# Bacteroides finegoldii                            1531351  ...
# Bacteroides ovatus                                 615396  ...
# Bacteroides sp902362375                            385922  ...
# Bacteroides nordii                                  17552  ...
# ...                                                   ...  ...
# Campylobacter_D coli_B                                  0  ...
# Helicobacter pylori_BU                                  0  ...
# Methanobacterium sp000499765                            0  ...
# Campylobacter fetus                                     0  ...
# Campylobacter_D coli_A                                  0  ...
#
#                               SRR32733691.bracken.out_num  \
# Bacteroides xylanisolvens                          515110
# Bacteroides finegoldii                              93588
# Bacteroides ovatus                                1273619
# Bacteroides sp902362375                            184016
# Bacteroides nordii                                 102020
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733692.bracken.out_num  \
# Bacteroides xylanisolvens                          483829
# Bacteroides finegoldii                              47202
# Bacteroides ovatus                                 625157
# Bacteroides sp902362375                            100142
# Bacteroides nordii                                   6228
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733693.bracken.out_num  \
# Bacteroides xylanisolvens                          192112
# Bacteroides finegoldii                             279165
# Bacteroides ovatus                                 260231
# Bacteroides sp902362375                             43224
# Bacteroides nordii                                  59793
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733694.bracken.out_num  \
# Bacteroides xylanisolvens                         5141498
# Bacteroides finegoldii                             158712
# Bacteroides ovatus                                1051579
# Bacteroides sp902362375                            263730
# Bacteroides nordii                                  13324
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733695.bracken.out_num  \
# Bacteroides xylanisolvens                          885775
# Bacteroides finegoldii                             335456
# Bacteroides ovatus                                 323376
# Bacteroides sp902362375                            103097
# Bacteroides nordii                                  14348
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733696.bracken.out_num  \
# Bacteroides xylanisolvens                          135885
# Bacteroides finegoldii                              23166
# Bacteroides ovatus                                 353907
# Bacteroides sp902362375                             54273
# Bacteroides nordii                                  87856
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733697.bracken.out_num  \
# Bacteroides xylanisolvens                           61316
# Bacteroides finegoldii                              16353
# Bacteroides ovatus                                   5248
# Bacteroides sp902362375                              4176
# Bacteroides nordii                                   2923
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733698.bracken.out_num  \
# Bacteroides xylanisolvens                           71793
# Bacteroides finegoldii                             262154
# Bacteroides ovatus                                 245473
# Bacteroides sp902362375                             37103
# Bacteroides nordii                                  37388
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733699.bracken.out_num  \
# Bacteroides xylanisolvens                           93594
# Bacteroides finegoldii                             215860
# Bacteroides ovatus                                  28510
# Bacteroides sp902362375                              8360
# Bacteroides nordii                                  14192
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
#                               SRR32733700.bracken.out_num
# Bacteroides xylanisolvens                          195599
# Bacteroides finegoldii                              29743
# Bacteroides ovatus                                 409488
# Bacteroides sp902362375                             67425
# Bacteroides nordii                                  27676
# ...                                                   ...
# Campylobacter_D coli_B                                  0
# Helicobacter pylori_BU                                  0
# Methanobacterium sp000499765                            0
# Campylobacter fetus                                     0
# Campylobacter_D coli_A                                  0
#
# [4630 rows x 851 columns]

# %%
brack_df.columns = brack_df.columns.str.extract(r'([^\.]+)\.bracken\.out_num')[0]
brack_df # to remove " bracken.out_num " extension----> to clean column name
# Out:
# 0                             SRR32732804  SRR32732805  SRR32732806  \
# Bacteroides xylanisolvens         3232092       383411        63773
# Bacteroides finegoldii             851026        34049        17527
# Bacteroides ovatus                 631604       195250        53197
# Bacteroides sp902362375            499300       117253        14670
# Bacteroides nordii                 123744        27246         8643
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732807  SRR32732808  SRR32732809  \
# Bacteroides xylanisolvens          204219      1464145       106125
# Bacteroides finegoldii              51546       102643         8398
# Bacteroides ovatus                4002970      1331243       101814
# Bacteroides sp902362375             85542       234381        15628
# Bacteroides nordii                 170255        31901         3207
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732810  SRR32732811  SRR32732813  \
# Bacteroides xylanisolvens          274709       232809      1179323
# Bacteroides finegoldii              63793        45654       137449
# Bacteroides ovatus                 622567       800555      2510966
# Bacteroides sp902362375             98329       120593       384453
# Bacteroides nordii                  37458         3211        56297
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732814  ...  SRR32733691  SRR32733692  \
# Bacteroides xylanisolvens         1384180  ...       515110       483829
# Bacteroides finegoldii            1531351  ...        93588        47202
# Bacteroides ovatus                 615396  ...      1273619       625157
# Bacteroides sp902362375            385922  ...       184016       100142
# Bacteroides nordii                  17552  ...       102020         6228
# ...                                   ...  ...          ...          ...
# Campylobacter_D coli_B                  0  ...            0            0
# Helicobacter pylori_BU                  0  ...            0            0
# Methanobacterium sp000499765            0  ...            0            0
# Campylobacter fetus                     0  ...            0            0
# Campylobacter_D coli_A                  0  ...            0            0
#
# 0                             SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens          192112      5141498       885775
# Bacteroides finegoldii             279165       158712       335456
# Bacteroides ovatus                 260231      1051579       323376
# Bacteroides sp902362375             43224       263730       103097
# Bacteroides nordii                  59793        13324        14348
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32733696  SRR32733697  SRR32733698  \
# Bacteroides xylanisolvens          135885        61316        71793
# Bacteroides finegoldii              23166        16353       262154
# Bacteroides ovatus                 353907         5248       245473
# Bacteroides sp902362375             54273         4176        37103
# Bacteroides nordii                  87856         2923        37388
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32733699  SRR32733700
# Bacteroides xylanisolvens           93594       195599
# Bacteroides finegoldii             215860        29743
# Bacteroides ovatus                  28510       409488
# Bacteroides sp902362375              8360        67425
# Bacteroides nordii                  14192        27676
# ...                                   ...          ...
# Campylobacter_D coli_B                  0            0
# Helicobacter pylori_BU                  0            0
# Methanobacterium sp000499765            0            0
# Campylobacter fetus                     0            0
# Campylobacter_D coli_A                  0            0
#
# [4630 rows x 851 columns]

# %%
brack_df.index = out_df['name'].values
brack_df
# Out:
# 0                             SRR32732804  SRR32732805  SRR32732806  \
# Bacteroides xylanisolvens         3232092       383411        63773
# Bacteroides finegoldii             851026        34049        17527
# Bacteroides ovatus                 631604       195250        53197
# Bacteroides sp902362375            499300       117253        14670
# Bacteroides nordii                 123744        27246         8643
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732807  SRR32732808  SRR32732809  \
# Bacteroides xylanisolvens          204219      1464145       106125
# Bacteroides finegoldii              51546       102643         8398
# Bacteroides ovatus                4002970      1331243       101814
# Bacteroides sp902362375             85542       234381        15628
# Bacteroides nordii                 170255        31901         3207
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732810  SRR32732811  SRR32732813  \
# Bacteroides xylanisolvens          274709       232809      1179323
# Bacteroides finegoldii              63793        45654       137449
# Bacteroides ovatus                 622567       800555      2510966
# Bacteroides sp902362375             98329       120593       384453
# Bacteroides nordii                  37458         3211        56297
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732814  ...  SRR32733691  SRR32733692  \
# Bacteroides xylanisolvens         1384180  ...       515110       483829
# Bacteroides finegoldii            1531351  ...        93588        47202
# Bacteroides ovatus                 615396  ...      1273619       625157
# Bacteroides sp902362375            385922  ...       184016       100142
# Bacteroides nordii                  17552  ...       102020         6228
# ...                                   ...  ...          ...          ...
# Campylobacter_D coli_B                  0  ...            0            0
# Helicobacter pylori_BU                  0  ...            0            0
# Methanobacterium sp000499765            0  ...            0            0
# Campylobacter fetus                     0  ...            0            0
# Campylobacter_D coli_A                  0  ...            0            0
#
# 0                             SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens          192112      5141498       885775
# Bacteroides finegoldii             279165       158712       335456
# Bacteroides ovatus                 260231      1051579       323376
# Bacteroides sp902362375             43224       263730       103097
# Bacteroides nordii                  59793        13324        14348
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32733696  SRR32733697  SRR32733698  \
# Bacteroides xylanisolvens          135885        61316        71793
# Bacteroides finegoldii              23166        16353       262154
# Bacteroides ovatus                 353907         5248       245473
# Bacteroides sp902362375             54273         4176        37103
# Bacteroides nordii                  87856         2923        37388
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32733699  SRR32733700
# Bacteroides xylanisolvens           93594       195599
# Bacteroides finegoldii             215860        29743
# Bacteroides ovatus                  28510       409488
# Bacteroides sp902362375              8360        67425
# Bacteroides nordii                  14192        27676
# ...                                   ...          ...
# Campylobacter_D coli_B                  0            0
# Helicobacter pylori_BU                  0            0
# Methanobacterium sp000499765            0            0
# Campylobacter fetus                     0            0
# Campylobacter_D coli_A                  0            0
#
# [4630 rows x 851 columns]

# %%
brack_df
# Out:
# 0                             SRR32732804  SRR32732805  SRR32732806  \
# Bacteroides xylanisolvens         3232092       383411        63773
# Bacteroides finegoldii             851026        34049        17527
# Bacteroides ovatus                 631604       195250        53197
# Bacteroides sp902362375            499300       117253        14670
# Bacteroides nordii                 123744        27246         8643
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732807  SRR32732808  SRR32732809  \
# Bacteroides xylanisolvens          204219      1464145       106125
# Bacteroides finegoldii              51546       102643         8398
# Bacteroides ovatus                4002970      1331243       101814
# Bacteroides sp902362375             85542       234381        15628
# Bacteroides nordii                 170255        31901         3207
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732810  SRR32732811  SRR32732813  \
# Bacteroides xylanisolvens          274709       232809      1179323
# Bacteroides finegoldii              63793        45654       137449
# Bacteroides ovatus                 622567       800555      2510966
# Bacteroides sp902362375             98329       120593       384453
# Bacteroides nordii                  37458         3211        56297
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32732814  ...  SRR32733691  SRR32733692  \
# Bacteroides xylanisolvens         1384180  ...       515110       483829
# Bacteroides finegoldii            1531351  ...        93588        47202
# Bacteroides ovatus                 615396  ...      1273619       625157
# Bacteroides sp902362375            385922  ...       184016       100142
# Bacteroides nordii                  17552  ...       102020         6228
# ...                                   ...  ...          ...          ...
# Campylobacter_D coli_B                  0  ...            0            0
# Helicobacter pylori_BU                  0  ...            0            0
# Methanobacterium sp000499765            0  ...            0            0
# Campylobacter fetus                     0  ...            0            0
# Campylobacter_D coli_A                  0  ...            0            0
#
# 0                             SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens          192112      5141498       885775
# Bacteroides finegoldii             279165       158712       335456
# Bacteroides ovatus                 260231      1051579       323376
# Bacteroides sp902362375             43224       263730       103097
# Bacteroides nordii                  59793        13324        14348
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32733696  SRR32733697  SRR32733698  \
# Bacteroides xylanisolvens          135885        61316        71793
# Bacteroides finegoldii              23166        16353       262154
# Bacteroides ovatus                 353907         5248       245473
# Bacteroides sp902362375             54273         4176        37103
# Bacteroides nordii                  87856         2923        37388
# ...                                   ...          ...          ...
# Campylobacter_D coli_B                  0            0            0
# Helicobacter pylori_BU                  0            0            0
# Methanobacterium sp000499765            0            0            0
# Campylobacter fetus                     0            0            0
# Campylobacter_D coli_A                  0            0            0
#
# 0                             SRR32733699  SRR32733700
# Bacteroides xylanisolvens           93594       195599
# Bacteroides finegoldii             215860        29743
# Bacteroides ovatus                  28510       409488
# Bacteroides sp902362375              8360        67425
# Bacteroides nordii                  14192        27676
# ...                                   ...          ...
# Campylobacter_D coli_B                  0            0
# Helicobacter pylori_BU                  0            0
# Methanobacterium sp000499765            0            0
# Campylobacter fetus                     0            0
# Campylobacter_D coli_A                  0            0
#
# [4630 rows x 851 columns]

# %%
import pandas as pd

# Assume brack_num_df is your DataFrame
# Example: brack_num_df = pd.read_csv('your_file.csv', index_col=0)

# Step 1: Convert counts to presence/absence (1 if count > 0, else 0)
presence_absence = (brack_df > 0).astype(int)#Creates a Boolean DataFrame (True if value > 0, False otherwise). Converts True → 1 and False → 0
#
# Step 2: Calculate prevalence (proportion of samples where species is present)
prevalence = presence_absence.mean(axis=1)

# Step 3: Filter species with prevalence
threshold = 0.9
selected_species = prevalence[prevalence > threshold].index

# Step 4: Filter the original DataFrame to include only selected species
filtered_df = brack_df.loc[selected_species]

# Step 5: Output the filtered table
print(f"Filtered table for species with prevalence > {threshold}:")
print(filtered_df)

# Optionally, save the filtered table to a CSV file
# filtered_df.to_csv('filtered_species_prevalence_above_10_percent.csv')
# Out:
# Filtered table for species with prevalence > 0.9:
# 0                          SRR32732804  SRR32732805  SRR32732806  SRR32732807  \
# Bacteroides xylanisolvens      3232092       383411        63773       204219
# Bacteroides finegoldii          851026        34049        17527        51546
# Bacteroides ovatus              631604       195250        53197      4002970
# Bacteroides sp902362375         499300       117253        14670        85542
# Bacteroides nordii              123744        27246         8643       170255
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                    0          236            0          791
# Leptotrichia wadei                   0           40          201           84
# Bruticola sp004554425                0          238            0          416
# MGYG000004312                        0          113          281           15
# Prevotella sp900769055               0            0            0          204
#
# 0                          SRR32732808  SRR32732809  SRR32732810  SRR32732811  \
# Bacteroides xylanisolvens      1464145       106125       274709       232809
# Bacteroides finegoldii          102643         8398        63793        45654
# Bacteroides ovatus             1331243       101814       622567       800555
# Bacteroides sp902362375         234381        15628        98329       120593
# Bacteroides nordii               31901         3207        37458         3211
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                  389           94          102          305
# Leptotrichia wadei                  87           25           55           54
# Bruticola sp004554425              279          102          655          340
# MGYG000004312                        0          634          135          273
# Prevotella sp900769055             392            0          733          887
#
# 0                          SRR32732813  SRR32732814  ...  SRR32733691  \
# Bacteroides xylanisolvens      1179323      1384180  ...       515110
# Bacteroides finegoldii          137449      1531351  ...        93588
# Bacteroides ovatus             2510966       615396  ...      1273619
# Bacteroides sp902362375         384453       385922  ...       184016
# Bacteroides nordii               56297        17552  ...       102020
# ...                                ...          ...  ...          ...
# Kosakonia cowanii                  371           39  ...         1006
# Leptotrichia wadei                  89            0  ...          309
# Bruticola sp004554425             1418          211  ...           40
# MGYG000004312                       46          215  ...          693
# Prevotella sp900769055              64            0  ...           59
#
# 0                          SRR32733692  SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens       483829       192112      5141498       885775
# Bacteroides finegoldii           47202       279165       158712       335456
# Bacteroides ovatus              625157       260231      1051579       323376
# Bacteroides sp902362375         100142        43224       263730       103097
# Bacteroides nordii                6228        59793        13324        14348
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                  370           19           22          278
# Leptotrichia wadei                 157           12           35           53
# Bruticola sp004554425               32          849            0          553
# MGYG000004312                       12           82          127          100
# Prevotella sp900769055             119           98            0          269
#
# 0                          SRR32733696  SRR32733697  SRR32733698  SRR32733699  \
# Bacteroides xylanisolvens       135885        61316        71793        93594
# Bacteroides finegoldii           23166        16353       262154       215860
# Bacteroides ovatus              353907         5248       245473        28510
# Bacteroides sp902362375          54273         4176        37103         8360
# Bacteroides nordii               87856         2923        37388        14192
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                   14          487          313          228
# Leptotrichia wadei                   0          146           15           27
# Bruticola sp004554425              393          225          168          175
# MGYG000004312                       30            0          362          157
# Prevotella sp900769055              74            0           51          333
#
# 0                          SRR32733700
# Bacteroides xylanisolvens       195599
# Bacteroides finegoldii           29743
# Bacteroides ovatus              409488
# Bacteroides sp902362375          67425
# Bacteroides nordii               27676
# ...                                ...
# Kosakonia cowanii                  666
# Leptotrichia wadei                 178
# Bruticola sp004554425              156
# MGYG000004312                       34
# Prevotella sp900769055             473
#
# [2096 rows x 851 columns]

# %%
brack_num_df=filtered_df
brack_num_df
# Out:
# 0                          SRR32732804  SRR32732805  SRR32732806  SRR32732807  \
# Bacteroides xylanisolvens      3232092       383411        63773       204219
# Bacteroides finegoldii          851026        34049        17527        51546
# Bacteroides ovatus              631604       195250        53197      4002970
# Bacteroides sp902362375         499300       117253        14670        85542
# Bacteroides nordii              123744        27246         8643       170255
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                    0          236            0          791
# Leptotrichia wadei                   0           40          201           84
# Bruticola sp004554425                0          238            0          416
# MGYG000004312                        0          113          281           15
# Prevotella sp900769055               0            0            0          204
#
# 0                          SRR32732808  SRR32732809  SRR32732810  SRR32732811  \
# Bacteroides xylanisolvens      1464145       106125       274709       232809
# Bacteroides finegoldii          102643         8398        63793        45654
# Bacteroides ovatus             1331243       101814       622567       800555
# Bacteroides sp902362375         234381        15628        98329       120593
# Bacteroides nordii               31901         3207        37458         3211
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                  389           94          102          305
# Leptotrichia wadei                  87           25           55           54
# Bruticola sp004554425              279          102          655          340
# MGYG000004312                        0          634          135          273
# Prevotella sp900769055             392            0          733          887
#
# 0                          SRR32732813  SRR32732814  ...  SRR32733691  \
# Bacteroides xylanisolvens      1179323      1384180  ...       515110
# Bacteroides finegoldii          137449      1531351  ...        93588
# Bacteroides ovatus             2510966       615396  ...      1273619
# Bacteroides sp902362375         384453       385922  ...       184016
# Bacteroides nordii               56297        17552  ...       102020
# ...                                ...          ...  ...          ...
# Kosakonia cowanii                  371           39  ...         1006
# Leptotrichia wadei                  89            0  ...          309
# Bruticola sp004554425             1418          211  ...           40
# MGYG000004312                       46          215  ...          693
# Prevotella sp900769055              64            0  ...           59
#
# 0                          SRR32733692  SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens       483829       192112      5141498       885775
# Bacteroides finegoldii           47202       279165       158712       335456
# Bacteroides ovatus              625157       260231      1051579       323376
# Bacteroides sp902362375         100142        43224       263730       103097
# Bacteroides nordii                6228        59793        13324        14348
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                  370           19           22          278
# Leptotrichia wadei                 157           12           35           53
# Bruticola sp004554425               32          849            0          553
# MGYG000004312                       12           82          127          100
# Prevotella sp900769055             119           98            0          269
#
# 0                          SRR32733696  SRR32733697  SRR32733698  SRR32733699  \
# Bacteroides xylanisolvens       135885        61316        71793        93594
# Bacteroides finegoldii           23166        16353       262154       215860
# Bacteroides ovatus              353907         5248       245473        28510
# Bacteroides sp902362375          54273         4176        37103         8360
# Bacteroides nordii               87856         2923        37388        14192
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                   14          487          313          228
# Leptotrichia wadei                   0          146           15           27
# Bruticola sp004554425              393          225          168          175
# MGYG000004312                       30            0          362          157
# Prevotella sp900769055              74            0           51          333
#
# 0                          SRR32733700
# Bacteroides xylanisolvens       195599
# Bacteroides finegoldii           29743
# Bacteroides ovatus              409488
# Bacteroides sp902362375          67425
# Bacteroides nordii               27676
# ...                                ...
# Kosakonia cowanii                  666
# Leptotrichia wadei                 178
# Bruticola sp004554425              156
# MGYG000004312                       34
# Prevotella sp900769055             473
#
# [2096 rows x 851 columns]

# %%
import pandas as pd
import numpy as np


# Step 1: Prevalence Filter (species present in at least 20% of samples)
min_samples = int(0.2 * brack_num_df.shape[1])  # 20% of 851 = 171 samples
non_zero_counts = (brack_num_df > 0).sum(axis=1)  # Count non-zero samples per species
prevalence_filtered_df = brack_num_df[non_zero_counts >= min_samples]
prevalence_filtered_df
# Out:
# 0                          SRR32732804  SRR32732805  SRR32732806  SRR32732807  \
# Bacteroides xylanisolvens      3232092       383411        63773       204219
# Bacteroides finegoldii          851026        34049        17527        51546
# Bacteroides ovatus              631604       195250        53197      4002970
# Bacteroides sp902362375         499300       117253        14670        85542
# Bacteroides nordii              123744        27246         8643       170255
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                    0          236            0          791
# Leptotrichia wadei                   0           40          201           84
# Bruticola sp004554425                0          238            0          416
# MGYG000004312                        0          113          281           15
# Prevotella sp900769055               0            0            0          204
#
# 0                          SRR32732808  SRR32732809  SRR32732810  SRR32732811  \
# Bacteroides xylanisolvens      1464145       106125       274709       232809
# Bacteroides finegoldii          102643         8398        63793        45654
# Bacteroides ovatus             1331243       101814       622567       800555
# Bacteroides sp902362375         234381        15628        98329       120593
# Bacteroides nordii               31901         3207        37458         3211
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                  389           94          102          305
# Leptotrichia wadei                  87           25           55           54
# Bruticola sp004554425              279          102          655          340
# MGYG000004312                        0          634          135          273
# Prevotella sp900769055             392            0          733          887
#
# 0                          SRR32732813  SRR32732814  ...  SRR32733691  \
# Bacteroides xylanisolvens      1179323      1384180  ...       515110
# Bacteroides finegoldii          137449      1531351  ...        93588
# Bacteroides ovatus             2510966       615396  ...      1273619
# Bacteroides sp902362375         384453       385922  ...       184016
# Bacteroides nordii               56297        17552  ...       102020
# ...                                ...          ...  ...          ...
# Kosakonia cowanii                  371           39  ...         1006
# Leptotrichia wadei                  89            0  ...          309
# Bruticola sp004554425             1418          211  ...           40
# MGYG000004312                       46          215  ...          693
# Prevotella sp900769055              64            0  ...           59
#
# 0                          SRR32733692  SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens       483829       192112      5141498       885775
# Bacteroides finegoldii           47202       279165       158712       335456
# Bacteroides ovatus              625157       260231      1051579       323376
# Bacteroides sp902362375         100142        43224       263730       103097
# Bacteroides nordii                6228        59793        13324        14348
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                  370           19           22          278
# Leptotrichia wadei                 157           12           35           53
# Bruticola sp004554425               32          849            0          553
# MGYG000004312                       12           82          127          100
# Prevotella sp900769055             119           98            0          269
#
# 0                          SRR32733696  SRR32733697  SRR32733698  SRR32733699  \
# Bacteroides xylanisolvens       135885        61316        71793        93594
# Bacteroides finegoldii           23166        16353       262154       215860
# Bacteroides ovatus              353907         5248       245473        28510
# Bacteroides sp902362375          54273         4176        37103         8360
# Bacteroides nordii               87856         2923        37388        14192
# ...                                ...          ...          ...          ...
# Kosakonia cowanii                   14          487          313          228
# Leptotrichia wadei                   0          146           15           27
# Bruticola sp004554425              393          225          168          175
# MGYG000004312                       30            0          362          157
# Prevotella sp900769055              74            0           51          333
#
# 0                          SRR32733700
# Bacteroides xylanisolvens       195599
# Bacteroides finegoldii           29743
# Bacteroides ovatus              409488
# Bacteroides sp902362375          67425
# Bacteroides nordii               27676
# ...                                ...
# Kosakonia cowanii                  666
# Leptotrichia wadei                 178
# Bruticola sp004554425              156
# MGYG000004312                       34
# Prevotella sp900769055             473
#
# [2096 rows x 851 columns]

# %%
non_zero_counts
# Out:
# Bacteroides xylanisolvens    846
# Bacteroides finegoldii       849
# Bacteroides ovatus           847
# Bacteroides sp902362375      846
# Bacteroides nordii           847
#                             ...
# Kosakonia cowanii            811
# Leptotrichia wadei           776
# Bruticola sp004554425        767
# MGYG000004312                781
# Prevotella sp900769055       815
# Length: 2096, dtype: int64

# %%
# Step 2: Abundance Filter ( mean relative abundance >= 0.0001)
# Calculate relative abundance (normalize by sample total)
relative_abundance = prevalence_filtered_df.div(prevalence_filtered_df.sum(axis=0), axis=1)#divides each entry in a column by that column’s sum
# Compute mean relative abundance across samples for each species
mean_relative_abundance = relative_abundance.mean(axis=1) #takes the mean across columns (across all samples) for each row (species).
mean_relative_abundance
# Out:
# Bacteroides xylanisolvens    0.012341
# Bacteroides finegoldii       0.003372
# Bacteroides ovatus           0.016068
# Bacteroides sp902362375      0.003865
# Bacteroides nordii           0.001303
#                                ...
# Kosakonia cowanii            0.000009
# Leptotrichia wadei           0.000002
# Bruticola sp004554425        0.000009
# MGYG000004312                0.000005
# Prevotella sp900769055       0.000008
# Length: 2096, dtype: float64

# %%
# Filter species with mean relative abundance >= 0.0001
abundance_threshold =0.0001#keeps species whose average relative abundance ≥ 0.0001 across samples
filtered_otu_df = prevalence_filtered_df[mean_relative_abundance >= abundance_threshold]
filtered_otu_df # cutoff value (0.01%) for filtering species.
# Out:
# 0                          SRR32732804  SRR32732805  SRR32732806  SRR32732807  \
# Bacteroides xylanisolvens      3232092       383411        63773       204219
# Bacteroides finegoldii          851026        34049        17527        51546
# Bacteroides ovatus              631604       195250        53197      4002970
# Bacteroides sp902362375         499300       117253        14670        85542
# Bacteroides nordii              123744        27246         8643       170255
# ...                                ...          ...          ...          ...
# Collinsella tanakaei                36           64          171            0
# Bifidobacterium infantis            18         2830           38            0
# UBA7185 sp900556545                 96         3257        23401           55
# Prevotella sp900544825               0           49            0          362
# RC9 sp000434935                      0           43           28          258
#
# 0                          SRR32732808  SRR32732809  SRR32732810  SRR32732811  \
# Bacteroides xylanisolvens      1464145       106125       274709       232809
# Bacteroides finegoldii          102643         8398        63793        45654
# Bacteroides ovatus             1331243       101814       622567       800555
# Bacteroides sp902362375         234381        15628        98329       120593
# Bacteroides nordii               31901         3207        37458         3211
# ...                                ...          ...          ...          ...
# Collinsella tanakaei                19          119        45464         3494
# Bifidobacterium infantis         13534        50443        21579         5558
# UBA7185 sp900556545               3687          637          418          277
# Prevotella sp900544825             130           51      4418203       283294
# RC9 sp000434935                     17           11          573         7399
#
# 0                          SRR32732813  SRR32732814  ...  SRR32733691  \
# Bacteroides xylanisolvens      1179323      1384180  ...       515110
# Bacteroides finegoldii          137449      1531351  ...        93588
# Bacteroides ovatus             2510966       615396  ...      1273619
# Bacteroides sp902362375         384453       385922  ...       184016
# Bacteroides nordii               56297        17552  ...       102020
# ...                                ...          ...  ...          ...
# Collinsella tanakaei                 0            0  ...           36
# Bifidobacterium infantis         54599          542  ...        29020
# UBA7185 sp900556545                117           96  ...         1619
# Prevotella sp900544825             172            0  ...          453
# RC9 sp000434935                     72            0  ...          134
#
# 0                          SRR32733692  SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens       483829       192112      5141498       885775
# Bacteroides finegoldii           47202       279165       158712       335456
# Bacteroides ovatus              625157       260231      1051579       323376
# Bacteroides sp902362375         100142        43224       263730       103097
# Bacteroides nordii                6228        59793        13324        14348
# ...                                ...          ...          ...          ...
# Collinsella tanakaei                 0          112           73           61
# Bifidobacterium infantis         90956           46       314443        26508
# UBA7185 sp900556545               1912          796          669         1591
# Prevotella sp900544825             157         1689            0           80
# RC9 sp000434935                     24          133            0          234
#
# 0                          SRR32733696  SRR32733697  SRR32733698  SRR32733699  \
# Bacteroides xylanisolvens       135885        61316        71793        93594
# Bacteroides finegoldii           23166        16353       262154       215860
# Bacteroides ovatus              353907         5248       245473        28510
# Bacteroides sp902362375          54273         4176        37103         8360
# Bacteroides nordii               87856         2923        37388        14192
# ...                                ...          ...          ...          ...
# Collinsella tanakaei                35           33          123           27
# Bifidobacterium infantis         32438           12         5456        10272
# UBA7185 sp900556545               8064          177         8727          710
# Prevotella sp900544825             426           99          290       268878
# RC9 sp000434935                    252          183      2319059           28
#
# 0                          SRR32733700
# Bacteroides xylanisolvens       195599
# Bacteroides finegoldii           29743
# Bacteroides ovatus              409488
# Bacteroides sp902362375          67425
# Bacteroides nordii               27676
# ...                                ...
# Collinsella tanakaei                49
# Bifidobacterium infantis        186136
# UBA7185 sp900556545                108
# Prevotella sp900544825             192
# RC9 sp000434935                    131
#
# [768 rows x 851 columns]

# %%
import pandas as pd
import numpy as np

# Step 3: Add pseudocount of 1 to handle zeros
otu_df_pseudo = filtered_otu_df + 1

# Step 4: CLR transformation function
def clr_transform(df):
    # Compute geometric mean for each sample (column)
    gm = np.exp(np.log(df).mean(axis=0))
    # Apply CLR: log(x_i / GM)
    clr_df = np.log(df / gm) #Divide each value in a column by that column’s geometric mean.
    return clr_df

#np.log(df) → Take log of all values (since we added pseudocount, no zero issue).

#.mean(axis=0) → Compute mean of log values per column (per sample).

#np.exp(...) → Reverse the log to get the geometric mean.

# Apply CLR transformation
otu_df_clr = clr_transform(otu_df_pseudo)

# Display the resulting CLR-transformed DataFrame
print(otu_df_clr)

# Optional: Save to file
# otu_df_clr.to_csv('OTU_Table_CRC_851_clr_filtered.tsv', sep='\t')
# Out:
# 0                          SRR32732804  SRR32732805  SRR32732806  SRR32732807  \
# Bacteroides xylanisolvens     7.264509     4.558990     3.285019     4.881701
# Bacteroides finegoldii        5.930067     2.137710     1.993473     3.504997
# Bacteroides ovatus            5.631888     3.884166     3.103694     7.857295
# Bacteroides sp902362375       5.396833     3.374222     1.815546     4.011522
# Bacteroides nordii            4.001847     1.914823     1.286538     4.699806
# ...                                ...          ...          ...          ...
# Collinsella tanakaei         -4.113214    -4.123488    -2.630588    -7.345252
# Bifidobacterium infantis     -4.779693    -0.349490    -4.114521    -7.345252
# UBA7185 sp900556545          -3.149421    -0.209007     2.282495    -3.319901
# Prevotella sp900544825       -7.724132    -4.385852    -7.778082    -1.450850
# RC9 sp000434935              -7.724132    -4.513686    -4.410786    -1.788424
#
# 0                          SRR32732808  SRR32732809  SRR32732810  SRR32732811  \
# Bacteroides xylanisolvens     5.852930     3.147604     3.947628     4.076506
# Bacteroides finegoldii        3.195170     0.611090     2.487571     2.447397
# Bacteroides ovatus            5.757772     3.106135     4.765764     5.311590
# Bacteroides sp902362375       4.020855     1.232106     2.920241     3.418713
# Bacteroides nordii            2.026572    -0.351375     1.955159    -0.206823
# ...                                ...          ...          ...          ...
# Collinsella tanakaei         -5.348120    -3.637286     2.148854    -0.122383
# Bifidobacterium infantis      1.169182     2.403841     1.403679     0.341702
# UBA7185 sp900556545          -0.131013    -1.966440    -2.537973    -2.653851
# Prevotella sp900544825       -3.468655    -4.473534     6.725400     4.272772
# RC9 sp000434935              -5.453481    -5.939871    -2.223214     0.627764
#
# 0                          SRR32732813  SRR32732814  ...  SRR32733691  \
# Bacteroides xylanisolvens     6.916987     6.566426  ...     5.044837
# Bacteroides finegoldii        4.767550     6.667468  ...     3.339368
# Bacteroides ovatus            7.672713     5.755829  ...     5.950073
# Bacteroides sp902362375       5.796114     5.289200  ...     4.015483
# Bacteroides nordii            3.874949     2.198787  ...     3.425633
# ...                                ...          ...  ...          ...
# Collinsella tanakaei         -7.063465    -7.574193  ...    -4.496383
# Bifidobacterium infantis      3.844324    -1.277084  ...     2.168474
# UBA7185 sp900556545          -2.292780    -2.999482  ...    -0.717119
# Prevotella sp900544825       -1.910173    -7.574193  ...    -1.989203
# RC9 sp000434935              -2.773006    -7.574193  ...    -3.202026
#
# 0                          SRR32733692  SRR32733693  SRR32733694  SRR32733695  \
# Bacteroides xylanisolvens     5.409534     3.254263     7.839703     4.769499
# Bacteroides finegoldii        3.082258     3.627986     4.361701     3.798528
# Bacteroides ovatus            5.665805     3.557753     6.252652     3.761853
# Bacteroides sp902362375       3.834399     1.762599     4.869533     2.618715
# Bacteroides nordii            1.057016     2.087085     1.884245     0.646715
# ...                                ...          ...          ...          ...
# Collinsella tanakaei         -7.679955    -4.184188    -3.309087    -4.797586
# Bifidobacterium infantis      3.738187    -5.061428     5.045409     1.260519
# UBA7185 sp900556545          -0.123527    -2.230721    -1.105874    -1.551974
# Prevotella sp900544825       -2.617360    -1.479092    -7.613152    -4.530272
# RC9 sp000434935              -4.461079    -4.013736    -7.613152    -3.465135
#
# 0                          SRR32733696  SRR32733697  SRR32733698  SRR32733699  \
# Bacteroides xylanisolvens     3.583510     2.913627     2.467994     3.514864
# Bacteroides finegoldii        1.814422     1.592043     3.763129     4.350522
# Bacteroides ovatus            4.540731     0.455608     3.697384     2.326177
# Bacteroides sp902362375       2.665739     0.227164     1.807918     1.099465
# Bacteroides nordii            3.147404    -0.129477     1.815570     1.628636
# ...                                ...          ...          ...          ...
# Collinsella tanakaei         -4.652543    -4.583824    -3.893280    -4.599664
# Bifidobacterium infantis      2.151055    -5.545236    -0.108907     1.305406
# UBA7185 sp900556545           0.759227    -2.928401     0.360730    -1.365196
# Prevotella sp900544825       -2.179278    -3.505015    -3.040239     4.570148
# RC9 sp000434935              -2.702672    -2.895249     5.943111    -4.564573
#
# 0                          SRR32733700
# Bacteroides xylanisolvens     3.778552
# Bacteroides finegoldii        1.895107
# Bacteroides ovatus            4.517390
# Bacteroides sp902362375       2.713511
# Bacteroides nordii            1.823082
# ...                                ...
# Collinsella tanakaei         -4.493252
# Bifidobacterium infantis      3.728963
# UBA7185 sp900556545          -3.713927
# Prevotella sp900544825       -3.142585
# RC9 sp000434935              -3.522473
#
# [768 rows x 851 columns]

# %%
otu_df_clr.T
# Out:
#              Bacteroides xylanisolvens  Bacteroides finegoldii  \
# 0
# SRR32732804                   7.264509                5.930067
# SRR32732805                   4.558990                2.137710
# SRR32732806                   3.285019                1.993473
# SRR32732807                   4.881701                3.504997
# SRR32732808                   5.852930                3.195170
# ...                                ...                     ...
# SRR32733696                   3.583510                1.814422
# SRR32733697                   2.913627                1.592043
# SRR32733698                   2.467994                3.763129
# SRR32733699                   3.514864                4.350522
# SRR32733700                   3.778552                1.895107
#
#              Bacteroides ovatus  Bacteroides sp902362375  Bacteroides nordii  \
# 0
# SRR32732804            5.631888                 5.396833            4.001847
# SRR32732805            3.884166                 3.374222            1.914823
# SRR32732806            3.103694                 1.815546            1.286538
# SRR32732807            7.857295                 4.011522            4.699806
# SRR32732808            5.757772                 4.020855            2.026572
# ...                         ...                      ...                 ...
# SRR32733696            4.540731                 2.665739            3.147404
# SRR32733697            0.455608                 0.227164           -0.129477
# SRR32733698            3.697384                 1.807918            1.815570
# SRR32733699            2.326177                 1.099465            1.628636
# SRR32733700            4.517390                 2.713511            1.823082
#
#              Bacteroides thetaiotaomicron  Bacteroides acidifaciens  \
# 0
# SRR32732804                      4.028527                  3.838231
# SRR32732805                      3.545425                  2.800761
# SRR32732806                      8.219860                  4.142998
# SRR32732807                      3.197691                  4.512879
# SRR32732808                      1.538412                  3.507479
# ...                                   ...                       ...
# SRR32733696                      5.901366                  1.613286
# SRR32733697                      6.387874                  2.011996
# SRR32733698                      2.673710                  1.014143
# SRR32733699                      4.831947                  2.545420
# SRR32733700                      4.414774                  2.267116
#
#              Bacteroides fragilis_A  Bacteroides sp900765785  \
# 0
# SRR32732804                3.588390                 3.576528
# SRR32732805                1.008048                 2.354856
# SRR32732806                0.056706                 5.326997
# SRR32732807                3.226782                 4.925770
# SRR32732808                0.361976                 2.816988
# ...                             ...                      ...
# SRR32733696                5.334044                 3.430306
# SRR32733697               -0.476815                 3.096365
# SRR32733698                0.207629                 1.051238
# SRR32733699               -0.096685                 2.898513
# SRR32733700                0.662810                 2.254968
#
#              Bacteroides faecis  ...  Collinsella sp003437035  \
# 0                                ...
# SRR32732804            3.486918  ...                -1.521596
# SRR32732805            1.315394  ...                 0.468831
# SRR32732806            5.501311  ...                 3.064475
# SRR32732807            2.788195  ...                -1.746830
# SRR32732808            1.125925  ...                -1.635768
# ...                         ...  ...                      ...
# SRR32733696            3.485973  ...                 1.090638
# SRR32733697            2.981893  ...                -0.269479
# SRR32733698            1.349149  ...                -1.529691
# SRR32733699            2.423936  ...                 0.473499
# SRR32733700            1.962795  ...                -0.465048
#
#              Collinsella sp900541125  Collinsella sp003479805  MGYG000003108  \
# 0
# SRR32732804                -1.554521                -1.898132      -1.915989
# SRR32732805                -1.511158                -2.365630       0.213501
# SRR32732806                -0.528867                -1.642517      -1.135595
# SRR32732807                -0.978782                -2.301827       0.585314
# SRR32732808                -2.080454                -2.822391      -1.098911
# ...                              ...                      ...            ...
# SRR32733696                 0.017166                -3.805245      -1.166188
# SRR32733697                -5.337596                -2.911688      -0.731177
# SRR32733698                -0.102878                -0.331501      -0.234694
# SRR32733699                 0.368412                -3.195670      -0.240668
# SRR32733700                -0.162256                -2.256807      -0.332496
#
#              Collinsella aerofaciens_F  Collinsella tanakaei  \
# 0
# SRR32732804                  -3.014601             -4.113214
# SRR32732805                   0.112846             -4.123488
# SRR32732806                   0.986752             -2.630588
# SRR32732807                  -4.254210             -7.345252
# SRR32732808                  -2.303598             -5.348120
# ...                                ...                   ...
# SRR32733696                   0.180869             -4.652543
# SRR32733697                  -3.728158             -4.583824
# SRR32733698                   0.152314             -3.893280
# SRR32733699                  -0.330466             -4.599664
# SRR32733700                  -2.123009             -4.493252
#
#              Bifidobacterium infantis  UBA7185 sp900556545  \
# 0
# SRR32732804                 -4.779693            -3.149421
# SRR32732805                 -0.349490            -0.209007
# SRR32732806                 -4.114521             2.282495
# SRR32732807                 -7.345252            -3.319901
# SRR32732808                  1.169182            -0.131013
# ...                               ...                  ...
# SRR32733696                  2.151055             0.759227
# SRR32733697                 -5.545236            -2.928401
# SRR32733698                 -0.108907             0.360730
# SRR32733699                  1.305406            -1.365196
# SRR32733700                  3.728963            -3.713927
#
#              Prevotella sp900544825  RC9 sp000434935
# 0
# SRR32732804               -7.724132        -7.724132
# SRR32732805               -4.385852        -4.513686
# SRR32732806               -7.778082        -4.410786
# SRR32732807               -1.450850        -1.788424
# SRR32732808               -3.468655        -5.453481
# ...                             ...              ...
# SRR32733696               -2.179278        -2.702672
# SRR32733697               -3.505015        -2.895249
# SRR32733698               -3.040239         5.943111
# SRR32733699                4.570148        -4.564573
# SRR32733700               -3.142585        -3.522473
#
# [851 rows x 768 columns]

# %%
otu_table=otu_df_clr.T # transpose the matrix row for sample and columns for species
otu_table
# Out:
#              Bacteroides xylanisolvens  Bacteroides finegoldii  \
# 0
# SRR32732804                   7.264509                5.930067
# SRR32732805                   4.558990                2.137710
# SRR32732806                   3.285019                1.993473
# SRR32732807                   4.881701                3.504997
# SRR32732808                   5.852930                3.195170
# ...                                ...                     ...
# SRR32733696                   3.583510                1.814422
# SRR32733697                   2.913627                1.592043
# SRR32733698                   2.467994                3.763129
# SRR32733699                   3.514864                4.350522
# SRR32733700                   3.778552                1.895107
#
#              Bacteroides ovatus  Bacteroides sp902362375  Bacteroides nordii  \
# 0
# SRR32732804            5.631888                 5.396833            4.001847
# SRR32732805            3.884166                 3.374222            1.914823
# SRR32732806            3.103694                 1.815546            1.286538
# SRR32732807            7.857295                 4.011522            4.699806
# SRR32732808            5.757772                 4.020855            2.026572
# ...                         ...                      ...                 ...
# SRR32733696            4.540731                 2.665739            3.147404
# SRR32733697            0.455608                 0.227164           -0.129477
# SRR32733698            3.697384                 1.807918            1.815570
# SRR32733699            2.326177                 1.099465            1.628636
# SRR32733700            4.517390                 2.713511            1.823082
#
#              Bacteroides thetaiotaomicron  Bacteroides acidifaciens  \
# 0
# SRR32732804                      4.028527                  3.838231
# SRR32732805                      3.545425                  2.800761
# SRR32732806                      8.219860                  4.142998
# SRR32732807                      3.197691                  4.512879
# SRR32732808                      1.538412                  3.507479
# ...                                   ...                       ...
# SRR32733696                      5.901366                  1.613286
# SRR32733697                      6.387874                  2.011996
# SRR32733698                      2.673710                  1.014143
# SRR32733699                      4.831947                  2.545420
# SRR32733700                      4.414774                  2.267116
#
#              Bacteroides fragilis_A  Bacteroides sp900765785  \
# 0
# SRR32732804                3.588390                 3.576528
# SRR32732805                1.008048                 2.354856
# SRR32732806                0.056706                 5.326997
# SRR32732807                3.226782                 4.925770
# SRR32732808                0.361976                 2.816988
# ...                             ...                      ...
# SRR32733696                5.334044                 3.430306
# SRR32733697               -0.476815                 3.096365
# SRR32733698                0.207629                 1.051238
# SRR32733699               -0.096685                 2.898513
# SRR32733700                0.662810                 2.254968
#
#              Bacteroides faecis  ...  Collinsella sp003437035  \
# 0                                ...
# SRR32732804            3.486918  ...                -1.521596
# SRR32732805            1.315394  ...                 0.468831
# SRR32732806            5.501311  ...                 3.064475
# SRR32732807            2.788195  ...                -1.746830
# SRR32732808            1.125925  ...                -1.635768
# ...                         ...  ...                      ...
# SRR32733696            3.485973  ...                 1.090638
# SRR32733697            2.981893  ...                -0.269479
# SRR32733698            1.349149  ...                -1.529691
# SRR32733699            2.423936  ...                 0.473499
# SRR32733700            1.962795  ...                -0.465048
#
#              Collinsella sp900541125  Collinsella sp003479805  MGYG000003108  \
# 0
# SRR32732804                -1.554521                -1.898132      -1.915989
# SRR32732805                -1.511158                -2.365630       0.213501
# SRR32732806                -0.528867                -1.642517      -1.135595
# SRR32732807                -0.978782                -2.301827       0.585314
# SRR32732808                -2.080454                -2.822391      -1.098911
# ...                              ...                      ...            ...
# SRR32733696                 0.017166                -3.805245      -1.166188
# SRR32733697                -5.337596                -2.911688      -0.731177
# SRR32733698                -0.102878                -0.331501      -0.234694
# SRR32733699                 0.368412                -3.195670      -0.240668
# SRR32733700                -0.162256                -2.256807      -0.332496
#
#              Collinsella aerofaciens_F  Collinsella tanakaei  \
# 0
# SRR32732804                  -3.014601             -4.113214
# SRR32732805                   0.112846             -4.123488
# SRR32732806                   0.986752             -2.630588
# SRR32732807                  -4.254210             -7.345252
# SRR32732808                  -2.303598             -5.348120
# ...                                ...                   ...
# SRR32733696                   0.180869             -4.652543
# SRR32733697                  -3.728158             -4.583824
# SRR32733698                   0.152314             -3.893280
# SRR32733699                  -0.330466             -4.599664
# SRR32733700                  -2.123009             -4.493252
#
#              Bifidobacterium infantis  UBA7185 sp900556545  \
# 0
# SRR32732804                 -4.779693            -3.149421
# SRR32732805                 -0.349490            -0.209007
# SRR32732806                 -4.114521             2.282495
# SRR32732807                 -7.345252            -3.319901
# SRR32732808                  1.169182            -0.131013
# ...                               ...                  ...
# SRR32733696                  2.151055             0.759227
# SRR32733697                 -5.545236            -2.928401
# SRR32733698                 -0.108907             0.360730
# SRR32733699                  1.305406            -1.365196
# SRR32733700                  3.728963            -3.713927
#
#              Prevotella sp900544825  RC9 sp000434935
# 0
# SRR32732804               -7.724132        -7.724132
# SRR32732805               -4.385852        -4.513686
# SRR32732806               -7.778082        -4.410786
# SRR32732807               -1.450850        -1.788424
# SRR32732808               -3.468655        -5.453481
# ...                             ...              ...
# SRR32733696               -2.179278        -2.702672
# SRR32733697               -3.505015        -2.895249
# SRR32733698               -3.040239         5.943111
# SRR32733699                4.570148        -4.564573
# SRR32733700               -3.142585        -3.522473
#
# [851 rows x 768 columns]

# %%
otu_table["Run_ID"]=otu_table.index
otu_table
# Out:
#              Bacteroides xylanisolvens  Bacteroides finegoldii  \
# 0
# SRR32732804                   7.264509                5.930067
# SRR32732805                   4.558990                2.137710
# SRR32732806                   3.285019                1.993473
# SRR32732807                   4.881701                3.504997
# SRR32732808                   5.852930                3.195170
# ...                                ...                     ...
# SRR32733696                   3.583510                1.814422
# SRR32733697                   2.913627                1.592043
# SRR32733698                   2.467994                3.763129
# SRR32733699                   3.514864                4.350522
# SRR32733700                   3.778552                1.895107
#
#              Bacteroides ovatus  Bacteroides sp902362375  Bacteroides nordii  \
# 0
# SRR32732804            5.631888                 5.396833            4.001847
# SRR32732805            3.884166                 3.374222            1.914823
# SRR32732806            3.103694                 1.815546            1.286538
# SRR32732807            7.857295                 4.011522            4.699806
# SRR32732808            5.757772                 4.020855            2.026572
# ...                         ...                      ...                 ...
# SRR32733696            4.540731                 2.665739            3.147404
# SRR32733697            0.455608                 0.227164           -0.129477
# SRR32733698            3.697384                 1.807918            1.815570
# SRR32733699            2.326177                 1.099465            1.628636
# SRR32733700            4.517390                 2.713511            1.823082
#
#              Bacteroides thetaiotaomicron  Bacteroides acidifaciens  \
# 0
# SRR32732804                      4.028527                  3.838231
# SRR32732805                      3.545425                  2.800761
# SRR32732806                      8.219860                  4.142998
# SRR32732807                      3.197691                  4.512879
# SRR32732808                      1.538412                  3.507479
# ...                                   ...                       ...
# SRR32733696                      5.901366                  1.613286
# SRR32733697                      6.387874                  2.011996
# SRR32733698                      2.673710                  1.014143
# SRR32733699                      4.831947                  2.545420
# SRR32733700                      4.414774                  2.267116
#
#              Bacteroides fragilis_A  Bacteroides sp900765785  \
# 0
# SRR32732804                3.588390                 3.576528
# SRR32732805                1.008048                 2.354856
# SRR32732806                0.056706                 5.326997
# SRR32732807                3.226782                 4.925770
# SRR32732808                0.361976                 2.816988
# ...                             ...                      ...
# SRR32733696                5.334044                 3.430306
# SRR32733697               -0.476815                 3.096365
# SRR32733698                0.207629                 1.051238
# SRR32733699               -0.096685                 2.898513
# SRR32733700                0.662810                 2.254968
#
#              Bacteroides faecis  ...  Collinsella sp900541125  \
# 0                                ...
# SRR32732804            3.486918  ...                -1.554521
# SRR32732805            1.315394  ...                -1.511158
# SRR32732806            5.501311  ...                -0.528867
# SRR32732807            2.788195  ...                -0.978782
# SRR32732808            1.125925  ...                -2.080454
# ...                         ...  ...                      ...
# SRR32733696            3.485973  ...                 0.017166
# SRR32733697            2.981893  ...                -5.337596
# SRR32733698            1.349149  ...                -0.102878
# SRR32733699            2.423936  ...                 0.368412
# SRR32733700            1.962795  ...                -0.162256
#
#              Collinsella sp003479805  MGYG000003108  \
# 0
# SRR32732804                -1.898132      -1.915989
# SRR32732805                -2.365630       0.213501
# SRR32732806                -1.642517      -1.135595
# SRR32732807                -2.301827       0.585314
# SRR32732808                -2.822391      -1.098911
# ...                              ...            ...
# SRR32733696                -3.805245      -1.166188
# SRR32733697                -2.911688      -0.731177
# SRR32733698                -0.331501      -0.234694
# SRR32733699                -3.195670      -0.240668
# SRR32733700                -2.256807      -0.332496
#
#              Collinsella aerofaciens_F  Collinsella tanakaei  \
# 0
# SRR32732804                  -3.014601             -4.113214
# SRR32732805                   0.112846             -4.123488
# SRR32732806                   0.986752             -2.630588
# SRR32732807                  -4.254210             -7.345252
# SRR32732808                  -2.303598             -5.348120
# ...                                ...                   ...
# SRR32733696                   0.180869             -4.652543
# SRR32733697                  -3.728158             -4.583824
# SRR32733698                   0.152314             -3.893280
# SRR32733699                  -0.330466             -4.599664
# SRR32733700                  -2.123009             -4.493252
#
#              Bifidobacterium infantis  UBA7185 sp900556545  \
# 0
# SRR32732804                 -4.779693            -3.149421
# SRR32732805                 -0.349490            -0.209007
# SRR32732806                 -4.114521             2.282495
# SRR32732807                 -7.345252            -3.319901
# SRR32732808                  1.169182            -0.131013
# ...                               ...                  ...
# SRR32733696                  2.151055             0.759227
# SRR32733697                 -5.545236            -2.928401
# SRR32733698                 -0.108907             0.360730
# SRR32733699                  1.305406            -1.365196
# SRR32733700                  3.728963            -3.713927
#
#              Prevotella sp900544825  RC9 sp000434935       Run_ID
# 0
# SRR32732804               -7.724132        -7.724132  SRR32732804
# SRR32732805               -4.385852        -4.513686  SRR32732805
# SRR32732806               -7.778082        -4.410786  SRR32732806
# SRR32732807               -1.450850        -1.788424  SRR32732807
# SRR32732808               -3.468655        -5.453481  SRR32732808
# ...                             ...              ...          ...
# SRR32733696               -2.179278        -2.702672  SRR32733696
# SRR32733697               -3.505015        -2.895249  SRR32733697
# SRR32733698               -3.040239         5.943111  SRR32733698
# SRR32733699                4.570148        -4.564573  SRR32733699
# SRR32733700               -3.142585        -3.522473  SRR32733700
#
# [851 rows x 769 columns]

# %%
otu_table = otu_table.reset_index(drop=True)
otu_table
# Out:
#      Bacteroides xylanisolvens  Bacteroides finegoldii  Bacteroides ovatus  \
# 0                     7.264509                5.930067            5.631888
# 1                     4.558990                2.137710            3.884166
# 2                     3.285019                1.993473            3.103694
# 3                     4.881701                3.504997            7.857295
# 4                     5.852930                3.195170            5.757772
# ..                         ...                     ...                 ...
# 846                   3.583510                1.814422            4.540731
# 847                   2.913627                1.592043            0.455608
# 848                   2.467994                3.763129            3.697384
# 849                   3.514864                4.350522            2.326177
# 850                   3.778552                1.895107            4.517390
#
#      Bacteroides sp902362375  Bacteroides nordii  \
# 0                   5.396833            4.001847
# 1                   3.374222            1.914823
# 2                   1.815546            1.286538
# 3                   4.011522            4.699806
# 4                   4.020855            2.026572
# ..                       ...                 ...
# 846                 2.665739            3.147404
# 847                 0.227164           -0.129477
# 848                 1.807918            1.815570
# 849                 1.099465            1.628636
# 850                 2.713511            1.823082
#
#      Bacteroides thetaiotaomicron  Bacteroides acidifaciens  \
# 0                        4.028527                  3.838231
# 1                        3.545425                  2.800761
# 2                        8.219860                  4.142998
# 3                        3.197691                  4.512879
# 4                        1.538412                  3.507479
# ..                            ...                       ...
# 846                      5.901366                  1.613286
# 847                      6.387874                  2.011996
# 848                      2.673710                  1.014143
# 849                      4.831947                  2.545420
# 850                      4.414774                  2.267116
#
#      Bacteroides fragilis_A  Bacteroides sp900765785  Bacteroides faecis  ...  \
# 0                  3.588390                 3.576528            3.486918  ...
# 1                  1.008048                 2.354856            1.315394  ...
# 2                  0.056706                 5.326997            5.501311  ...
# 3                  3.226782                 4.925770            2.788195  ...
# 4                  0.361976                 2.816988            1.125925  ...
# ..                      ...                      ...                 ...  ...
# 846                5.334044                 3.430306            3.485973  ...
# 847               -0.476815                 3.096365            2.981893  ...
# 848                0.207629                 1.051238            1.349149  ...
# 849               -0.096685                 2.898513            2.423936  ...
# 850                0.662810                 2.254968            1.962795  ...
#
#      Collinsella sp900541125  Collinsella sp003479805  MGYG000003108  \
# 0                  -1.554521                -1.898132      -1.915989
# 1                  -1.511158                -2.365630       0.213501
# 2                  -0.528867                -1.642517      -1.135595
# 3                  -0.978782                -2.301827       0.585314
# 4                  -2.080454                -2.822391      -1.098911
# ..                       ...                      ...            ...
# 846                 0.017166                -3.805245      -1.166188
# 847                -5.337596                -2.911688      -0.731177
# 848                -0.102878                -0.331501      -0.234694
# 849                 0.368412                -3.195670      -0.240668
# 850                -0.162256                -2.256807      -0.332496
#
#      Collinsella aerofaciens_F  Collinsella tanakaei  \
# 0                    -3.014601             -4.113214
# 1                     0.112846             -4.123488
# 2                     0.986752             -2.630588
# 3                    -4.254210             -7.345252
# 4                    -2.303598             -5.348120
# ..                         ...                   ...
# 846                   0.180869             -4.652543
# 847                  -3.728158             -4.583824
# 848                   0.152314             -3.893280
# 849                  -0.330466             -4.599664
# 850                  -2.123009             -4.493252
#
#      Bifidobacterium infantis  UBA7185 sp900556545  Prevotella sp900544825  \
# 0                   -4.779693            -3.149421               -7.724132
# 1                   -0.349490            -0.209007               -4.385852
# 2                   -4.114521             2.282495               -7.778082
# 3                   -7.345252            -3.319901               -1.450850
# 4                    1.169182            -0.131013               -3.468655
# ..                        ...                  ...                     ...
# 846                  2.151055             0.759227               -2.179278
# 847                 -5.545236            -2.928401               -3.505015
# 848                 -0.108907             0.360730               -3.040239
# 849                  1.305406            -1.365196                4.570148
# 850                  3.728963            -3.713927               -3.142585
#
#      RC9 sp000434935       Run_ID
# 0          -7.724132  SRR32732804
# 1          -4.513686  SRR32732805
# 2          -4.410786  SRR32732806
# 3          -1.788424  SRR32732807
# 4          -5.453481  SRR32732808
# ..               ...          ...
# 846        -2.702672  SRR32733696
# 847        -2.895249  SRR32733697
# 848         5.943111  SRR32733698
# 849        -4.564573  SRR32733699
# 850        -3.522473  SRR32733700
#
# [851 rows x 769 columns]

# %%
metadata=pd.read_csv("/content/meta_dta.csv")
metadata['Class_Label'] = metadata['Health_status'].apply(lambda x: 1 if x == 'HEALTHY' else 0)

metadata = metadata.rename(columns={'Unnamed: 0': 'Run'})
print(metadata.head())
# Out:
#            Run  Age     Sex    BMI Phenotype Health_status  Class_Label
# 0  SRR32732804   64  female  25.33   Adenoma   NON-HEALTHY            0
# 1  SRR32732805   72  female  24.85   Adenoma   NON-HEALTHY            0
# 2  SRR32732806   71  female  31.79   Adenoma   NON-HEALTHY            0
# 3  SRR32732807   71  female  21.92   Control       HEALTHY            1
# 4  SRR32732808   59  female  29.53   Adenoma   NON-HEALTHY            0

# %%
merged_df = pd.merge(otu_table, metadata, left_on='Run_ID', right_on="Run")
merged_df
# Out:
#      Bacteroides xylanisolvens  Bacteroides finegoldii  Bacteroides ovatus  \
# 0                     7.264509                5.930067            5.631888
# 1                     4.558990                2.137710            3.884166
# 2                     3.285019                1.993473            3.103694
# 3                     4.881701                3.504997            7.857295
# 4                     5.852930                3.195170            5.757772
# ..                         ...                     ...                 ...
# 846                   3.583510                1.814422            4.540731
# 847                   2.913627                1.592043            0.455608
# 848                   2.467994                3.763129            3.697384
# 849                   3.514864                4.350522            2.326177
# 850                   3.778552                1.895107            4.517390
#
#      Bacteroides sp902362375  Bacteroides nordii  \
# 0                   5.396833            4.001847
# 1                   3.374222            1.914823
# 2                   1.815546            1.286538
# 3                   4.011522            4.699806
# 4                   4.020855            2.026572
# ..                       ...                 ...
# 846                 2.665739            3.147404
# 847                 0.227164           -0.129477
# 848                 1.807918            1.815570
# 849                 1.099465            1.628636
# 850                 2.713511            1.823082
#
#      Bacteroides thetaiotaomicron  Bacteroides acidifaciens  \
# 0                        4.028527                  3.838231
# 1                        3.545425                  2.800761
# 2                        8.219860                  4.142998
# 3                        3.197691                  4.512879
# 4                        1.538412                  3.507479
# ..                            ...                       ...
# 846                      5.901366                  1.613286
# 847                      6.387874                  2.011996
# 848                      2.673710                  1.014143
# 849                      4.831947                  2.545420
# 850                      4.414774                  2.267116
#
#      Bacteroides fragilis_A  Bacteroides sp900765785  Bacteroides faecis  ...  \
# 0                  3.588390                 3.576528            3.486918  ...
# 1                  1.008048                 2.354856            1.315394  ...
# 2                  0.056706                 5.326997            5.501311  ...
# 3                  3.226782                 4.925770            2.788195  ...
# 4                  0.361976                 2.816988            1.125925  ...
# ..                      ...                      ...                 ...  ...
# 846                5.334044                 3.430306            3.485973  ...
# 847               -0.476815                 3.096365            2.981893  ...
# 848                0.207629                 1.051238            1.349149  ...
# 849               -0.096685                 2.898513            2.423936  ...
# 850                0.662810                 2.254968            1.962795  ...
#
#      Prevotella sp900544825  RC9 sp000434935       Run_ID          Run  Age  \
# 0                 -7.724132        -7.724132  SRR32732804  SRR32732804   64
# 1                 -4.385852        -4.513686  SRR32732805  SRR32732805   72
# 2                 -7.778082        -4.410786  SRR32732806  SRR32732806   71
# 3                 -1.450850        -1.788424  SRR32732807  SRR32732807   71
# 4                 -3.468655        -5.453481  SRR32732808  SRR32732808   59
# ..                      ...              ...          ...          ...  ...
# 846               -2.179278        -2.702672  SRR32733696  SRR32733696   57
# 847               -3.505015        -2.895249  SRR32733697  SRR32733697   66
# 848               -3.040239         5.943111  SRR32733698  SRR32733698   63
# 849                4.570148        -4.564573  SRR32733699  SRR32733699   71
# 850               -3.142585        -3.522473  SRR32733700  SRR32733700   72
#
#         Sex    BMI  Phenotype  Health_status  Class_Label
# 0    female  25.33    Adenoma    NON-HEALTHY            0
# 1    female  24.85    Adenoma    NON-HEALTHY            0
# 2    female  31.79    Adenoma    NON-HEALTHY            0
# 3    female  21.92    Control        HEALTHY            1
# 4    female  29.53    Adenoma    NON-HEALTHY            0
# ..      ...    ...        ...            ...          ...
# 846  female  21.28    Adenoma    NON-HEALTHY            0
# 847  female  23.29    Adenoma    NON-HEALTHY            0
# 848  female  19.76    Control        HEALTHY            1
# 849  female  29.12    Adenoma    NON-HEALTHY            0
# 850  female  25.96    Adenoma    NON-HEALTHY            0
#
# [851 rows x 776 columns]

# %%
# Drop metadata columns, keeping Run_ID and taxa columns
metadata_columns = ['Sex', 'BMI', 'Phenotype','Age', 'Health_status','Run_ID','Run', 'Class_Label']
X = merged_df.drop(columns=metadata_columns)

# Extract the target variable (Class_Label)
y = merged_df['Class_Label']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 846    0
# 847    0
# 848    1
# 849    0
# 850    0
# Name: Class_Label, Length: 851, dtype: int64

# %% [markdown]
# # **Hyperparameter Tuning**
# # ⌛

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.feature_selection import SelectKBest, f_classif, RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
# Step 1: Feature Selection
# We'll use two methods: univariate selection (ANOVA F-test) and recursive feature elimination (RFE) with RandomForest

# 1.1 Univariate feature selection: Select top k features based on ANOVA F-test
selector = SelectKBest(score_func=f_classif, k=100)  # Select top 100 features (adjust k as needed)
X_selected_uni = selector.fit_transform(X, y)
selected_features_uni = X.columns[selector.get_support()].tolist()
print(f"Selected {len(selected_features_uni)} features using ANOVA F-test: {selected_features_uni}")

# 1.2 RFE with RandomForest
rf = RandomForestClassifier(random_state=42)
rfe = RFE(estimator=rf, n_features_to_select=100, step=0.1)  # Select top 100 features
X_selected_rfe = rfe.fit_transform(X, y)
selected_features_rfe = X.columns[rfe.support_].tolist()
print(f"Selected {len(selected_features_rfe)} features using RFE: {selected_features_rfe}")

# For simplicity, we'll proceed with univariate selected features (X_selected_uni)
# You can switch to X_selected_rfe if preferred
X_selected = X_selected_uni

# Step 2: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42, stratify=y)

# Standardize features (important for SVM and Logistic Regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 3: Model Building and Hyperparameter Tuning
# We'll tune and compare three models: RandomForest, SVM, LogisticRegression

# Define models and parameter grids
models = {
    'RandomForest': {
        'model': RandomForestClassifier(random_state=42),
        'params': {
            'n_estimators': [50, 100, 200],
            'max_depth': [None, 10, 20],
            'min_samples_split': [2, 5, 10]
        }
    },
    'SVM': {
        'model': SVC(probability=True, random_state=42),
        'params': {
            'C': [0.1, 1, 10],
            'kernel': ['linear', 'rbf'],
            'gamma': ['scale', 'auto']
        }
    },
    'LogisticRegression': {
        'model': LogisticRegression(max_iter=1000, random_state=42),
        'params': {
            'C': [0.1, 1, 10],
            'solver': ['liblinear', 'lbfgs']
        }
    }
}

# Dictionary to store results
results = {}

# Hyperparameter tuning with GridSearchCV and 5-fold stratified CV
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, config in models.items():
    print(f"Tuning {name}...")
    grid_search = GridSearchCV(estimator=config['model'], param_grid=config['params'],
                               cv=cv, scoring='f1', n_jobs=-1, verbose=1)
    grid_search.fit(X_train_scaled, y_train)

    best_model = grid_search.best_estimator_
    print(f"Best parameters for {name}: {grid_search.best_params_}")

    # Evaluate on test set
    y_pred = best_model.predict(X_test_scaled)
    y_prob = best_model.predict_proba(X_test_scaled)[:, 1] if hasattr(best_model, 'predict_proba') else None

    results[name] = {
        'best_params': grid_search.best_params_,
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred),
        'f1': f1_score(y_test, y_pred),
        'roc_auc': roc_auc_score(y_test, y_prob) if y_prob is not None else None,
        'classification_report': classification_report(y_test, y_pred)
    }

# Step 4: Evaluation and Comparison
# Print results for each model
for name, metrics in results.items():
    print(f"\n{name} Performance:")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"Precision: {metrics['precision']:.4f}")
    print(f"Recall: {metrics['recall']:.4f}")
    print(f"F1-Score: {metrics['f1']:.4f}")
    print(f"ROC-AUC: {metrics['roc_auc']:.4f}" if metrics['roc_auc'] is not None else "ROC-AUC: N/A")
    print("Classification Report:")
    print(metrics['classification_report'])

# Compare models in a DataFrame
comparison_df = pd.DataFrame({
    'Model': list(results.keys()),
    'Accuracy': [results[name]['accuracy'] for name in results],
    'Precision': [results[name]['precision'] for name in results],
    'Recall': [results[name]['recall'] for name in results],
    'F1-Score': [results[name]['f1'] for name in results],
    'ROC-AUC': [results[name]['roc_auc'] if results[name]['roc_auc'] is not None else 'N/A' for name in results]
})

print("\nModel Comparison:")
print(comparison_df)
# Out:
# Selected 100 features using ANOVA F-test: ['Bacteroides sp900761785', 'MGYG000001977', 'Bacteroides bouchesdurhonensis', 'Bacteroides sp900547205', 'Bacteroides oleiciplenus', 'Bacteroides intestinalis', 'Bacteroides sp900556215', 'MGYG000004876', 'MGYG000001780', 'Bacteroides togonis', 'MGYG000004188', 'Phocaeicola mediterraneensis', 'Phocaeicola sp900546355', 'Prevotella sp000436595', 'Parabacteroides sp900760525', 'Parabacteroides sp900548175', 'Parabacteroides sp900540715', 'UBA1232 sp900544815', 'Gemmiger variabilis', 'Gemmiger sp900539695', 'Angelakisella sp900547385', 'CAG-217 sp000436335', 'CAG-177 sp003514385', 'Dysosmobacter welbionis', 'Dysosmobacter sp014297375', 'Dysosmobacter sp900752075', 'MGYG000002229', 'Lawsonibacter sp902363045', 'Lawsonibacter sp900066825', 'Lawsonibacter sp900066645', 'Lawsonibacter asaccharolyticus', 'Lawsonibacter sp900754605', 'Lawsonibacter sp900764755', 'Intestinimonas massiliensis', 'CAG-83 sp900555735', 'CAG-83 sp000435555', 'CAG-83 sp900548615', 'CAG-83 sp900545495', 'CAG-83 sp003539495', 'MGYG000004004', 'CAG-83 sp003487665', 'Flavonifractor plautii', 'MGYG000002073', 'CAG-110 sp900544705', 'MGYG000001632', 'CAG-170 sp900545925', 'MGYG000002085', 'CAG-170 sp000436735', 'CAG-170 sp000432135', 'CAG-170 sp002404795', 'MGYG000002726', 'UBA1777 sp900549485', 'ER4 sp900317525', 'F23-B02 sp001916715', 'F23-B02 sp900545805', 'F23-B02 sp002472405', 'UBA5446 sp900545405', 'MGYG000002696', 'Blautia_A wexlerae_A', 'Blautia_A caecimuris', 'Blautia_A wexlerae_B', 'Blautia_A sp003471165', 'Blautia_A hydrogenotrophica', 'MGYG000003822', 'Blautia_A sp900549015', 'Mediterraneibacter torques', 'Blautia sp900541955', 'Blautia sp003287895', 'MGYG000002738', 'Blautia sp000432195', 'Blautia hansenii', 'Anaerobutyricum hallii', 'Enterocloster sp001517625', 'Enterocloster sp000155435', 'MGYG000004677', 'UMGS1370 sp900542035', 'Clostridium_Q saccharolyticum_A', 'Clostridium_Q sp003024715', 'Clostridium_Q sp000435655', 'UBA9502 sp900538475', 'UBA9502 sp900540335', 'Schaedlerella glycyrrhizinilytica', 'UBA11774 sp003507655', 'Eubacterium_G sp900550135', 'AF33-28 sp003477885', 'Anaerotignum lactatifermentans', 'UMGS1670 sp900548595', 'UBA1191 sp900549125', 'QALS01 sp900552625', 'Firm-11 sp900540045', 'SFEL01 sp004557245', 'PeH17 sp000435055', 'UMGS1241 sp900550525', 'UMGS1241 sp900549955', 'MGYG000004894', 'Faecalibacillus faecis', 'Merdibacter sp900543035', 'Holdemanella sp002299315', 'Longicatena caecimuris', 'Collinsella aerofaciens_F']
# Selected 100 features using RFE: ['Bacteroides caccae', 'Bacteroides intestinalis', 'Phocaeicola mediterraneensis', 'Phocaeicola plebeius_A', 'Prevotella oris', 'Prevotella sp900556395', 'Prevotella sp003447235', 'Paraprevotella xylaniphila', 'Prevotellamassilia timonensis', 'Parabacteroides sp900760525', 'Alistipes putredinis', 'Alistipes finegoldii', 'Tidjanibacter inops_A', 'Alistipes_A ihumii', 'Butyricimonas virosa', 'UBA1232 sp900544815', 'Coprobacter fastidiosus', 'UMGS966 sp900547185', 'Negativibacillus massiliensis', 'MGYG000003895', 'UBA1417 sp003531055', 'Acutalibacter sp000435395', 'Anaeromassilibacillus sp001305115', 'MGYG000004159', 'Eubacterium_R sp000436835', 'Eubacterium_R sp000434995', 'Eubacterium_R sp900539425', 'MGYG000004116', 'MGYG000003211', 'Marseille-P4683 sp900232885', 'CAG-177 sp003514385', 'Dysosmobacter welbionis', 'Dysosmobacter sp014297375', 'Dysosmobacter sp000436875', 'MGYG000002229', 'Lawsonibacter sp000177015', 'Lawsonibacter sp900764755', 'CAG-83 sp003539495', 'CAG-110 sp900544975', 'MGYG000002726', 'F23-B02 sp001916715', 'UBA5446 sp900546485', 'NK3B98 sp900758315', 'CAG-103 sp900543625', 'MGYG000002696', 'UBA738 sp003522945', 'UMGS911 sp003343545', 'UMGS1696 sp900753285', 'Blautia_A sp003471165', 'Blautia_A sp900066145', 'Blautia_A hydrogenotrophica', 'MGYG000003822', 'Blautia_A obeum_B', 'Blautia_A obeum', 'Blautia_A sp900551715', 'Blautia_A sp900549015', 'Roseburia hominis', 'Mediterraneibacter torques', 'Blautia sp000432195', 'Blautia sp900753905', 'Eisenbergiella sp900066775', 'Anaerobutyricum hallii', 'Anaerobutyricum soehngenii', 'TF01-11 sp003529475', 'TF01-11 sp001916135', 'Enterocloster sp000155435', 'UBA7182 sp003480725', 'UMGS1370 sp900542035', 'Clostridium_Q sp003024715', 'UBA9502 sp900538475', 'UBA9502 sp900540335', 'Butyrivibrio_A crossotus', 'Coprococcus eutactus', 'Coprococcus sp900761435', 'Eubacterium_I ramulus', 'Eubacterium_I ramulus_A', 'Lacrimispora sp000526575', 'CAG-127 sp900767585', 'CAG-127 sp900553925', 'AF33-28 sp003477885', 'CAG-590 sp900544905', 'NSJ-32 sp014384895', 'MGYG000004775', 'CAG-145 sp000435715', 'UBA1191 sp900549125', 'Emergencia timonensis', 'CAG-238 sp900542245', 'CAG-354 sp900552655', 'QALS01 sp900552625', 'UBA11524 sp000437595', 'UMGS743 sp900545085', 'HGM11616 sp900761075', 'Erysipelatoclostridium ramosum', 'Faecalibacillus faecis', 'Merdibacter sp900543035', 'Holdemanella sp002299315', 'Bilophila sp900550745', 'CAG-1427 sp000435675', 'Collinsella aerofaciens_F', 'RC9 sp000434935']
# Tuning RandomForest...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters for RandomForest: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50}
# Tuning SVM...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters for SVM: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Tuning LogisticRegression...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters for LogisticRegression: {'C': 0.1, 'solver': 'liblinear'}
#
# RandomForest Performance:
# Accuracy: 0.5614
# Precision: 0.5591
# Recall: 0.6047
# F1-Score: 0.5810
# ROC-AUC: 0.5840
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.52      0.54        85
#            1       0.56      0.60      0.58        86
#
#     accuracy                           0.56       171
#    macro avg       0.56      0.56      0.56       171
# weighted avg       0.56      0.56      0.56       171
#
#
# SVM Performance:
# Accuracy: 0.6082
# Precision: 0.6022
# Recall: 0.6512
# F1-Score: 0.6257
# ROC-AUC: 0.5985
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59        85
#            1       0.60      0.65      0.63        86
#
#     accuracy                           0.61       171
#    macro avg       0.61      0.61      0.61       171
# weighted avg       0.61      0.61      0.61       171
#
#
# LogisticRegression Performance:
# Accuracy: 0.5146
# Precision: 0.5165
# Recall: 0.5465
# F1-Score: 0.5311
# ROC-AUC: 0.5382
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      0.48      0.50        85
#            1       0.52      0.55      0.53        86
#
#     accuracy                           0.51       171
#    macro avg       0.51      0.51      0.51       171
# weighted avg       0.51      0.51      0.51       171
#
#
# Model Comparison:
#                 Model  Accuracy  Precision    Recall  F1-Score   ROC-AUC
# 0        RandomForest  0.561404   0.559140  0.604651  0.581006  0.583995
# 1                 SVM  0.608187   0.602151  0.651163  0.625698  0.598495
# 2  LogisticRegression  0.514620   0.516484  0.546512  0.531073  0.538167

# %%
# Visualize comparison (bar plot for F1-Score)
plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='F1-Score', data=comparison_df)
plt.title('Model Comparison by F1-Score')
plt.ylabel('F1-Score')
plt.show()

# Optional: Cross-validation scores for the best model (e.g., RandomForest)
best_model_name = max(results, key=lambda x: results[x]['f1'])  # Select based on F1
best_model = models[best_model_name]['model'].set_params(**results[best_model_name]['best_params'])
cv_scores = cross_val_score(best_model, X_selected, y, cv=5, scoring='f1')
print(f"\nCross-Validation F1-Scores for {best_model_name}: {cv_scores}")
print(f"Mean CV F1-Score: {cv_scores.mean():.4f}")
# Out:
# Cross-Validation F1-Scores for SVM: [0.52873563 0.53333333 0.47272727 0.56969697 0.48192771]
# Mean CV F1-Score: 0.5173
